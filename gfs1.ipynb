# %%
import pyrebase

# %%
import numpy as np
import pandas as pd
import json

# %%
fbcon = {
  "apiKey" : "AIzaSyD7lGnNysCEn_8lTiYr6Ry5bJ6RPXwAupI",
  "authDomain" : "example-anxiety.firebaseapp.com",
  "databaseURL" : "https://example-anxiety-default-rtdb.firebaseio.com",
  "projectId" : "example-anxiety",
  "storageBucket": "example-anxiety.appspot.com",
  "messagingSenderId" : "822878015975",
  "appId" : "1:822878015975:web:45189ff5da85dd02d4ed42",
  "measurementId" : "G-H5J9DFFY5P"
}

FB = pyrebase.initialize_app(fbcon)
db = FB.database()

# %%
from datetime import datetime
import pytz

local_time = pytz.timezone("Asia/Jakarta")
time = datetime.now(local_time).strftime("%d %b %Y %H:%M:%S")

print("date and time =", time)
# Out:
# date and time = 20 Jul 2021 17:43:38

# %%
import pandas as pd
data_gejala = pd.read_excel (r'nilai_gfs.xlsx')
data_gejala.tail(38)
# Out:
#     no kode                                         gejala gfs  tinggi  rendah
# 0    1   g1         Kecemasan dan kekhawatiran yang berlebihan      90      10
# 1    2   g2                  Jantung berdebar-debar berlebihan      80      20
# 2    3   g3                             Berkeringat berlebihan      80      20
# 3    4   g4                     Bagian tubuh menjadi gemetaran      90      10
# 4    5   g5                        Kesulitan dalam konsentrasi      70      30
# 5    6   g6       Merasa resah dan tidak dapat berpikir jernih      90      10
# 6    7   g7      Adanya prilaku menghindar dari situasi sosial     100      10
# 7    8   g8  Ketakutan / kecemasan saat bertemu orang baru ...      90      20
# 8    9   g9  Kecemasan akan dicermati atau nilai buruk oleh...     100      10
# 9   10  g10  Ketakutan / kecemasan berada di situasi yang r...     100      10
# 10  11  g11  Keterpaparan dengan pemicu menyebabkan otot te...      90      20
# ...

# %%
#mengisi nilai inferensi

inferensi = {
    "tinggi":100,
    "rendah":10
}

# %%
#ngambil semua jawaban dari firebase
res = db.child("Pengujian").order_by_child("Proses").equal_to("Belum").get()
a = json.dumps(res.val())
b = json.loads(a)
for key in b:
  user = key
jawaban = db.child("Pengujian").child(user).child("Jawaban").get() 
print(jawaban.val())

#ambil index jawaban
list_gejala=[]
c = json.dumps(jawaban.val())
d = json.loads(c)
for key in d:
  list_gejala.append(key)
print(list_gejala)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pyrebase\pyrebase.py in raise_detailed_error(request_object)
#     511     try:
# --> 512         request_object.raise_for_status()
#     513     except HTTPError as e:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\requests\models.py in raise_for_status(self)
#     942         if http_error_msg:
# --> 943             raise HTTPError(http_error_msg, response=self)
#     944
#
# HTTPError: 400 Client Error: Bad Request for url: https://example-anxiety-default-rtdb.firebaseio.com/Pengujian.json?orderBy=%22Proses%22&equalTo=%22Belum%22
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-39eac387cd2a> in <module>
# ...
